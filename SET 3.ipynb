# %%
# import os
# from PIL import Image
# import numpy as np

# # Paths for dataset and output
# train_ct_path = "D:/Dataset/images/CT/trainA"
# train_mri_path = "D:/Dataset/images/MRI/trainB"
# test_ct_path = "D:/Dataset/images/CT/testA"
# test_mri_path = "D:/Dataset/images/MRI/testB"
# train_pet_path = "D:/Dataset/images/PET/trainc"
# test_pet_path = "D:/Dataset/images/PET/testc"
# output_train_path = "D:/Dataset/Fused Image/train"
# output_test_path = "D:/Dataset/Fused Image/test"

# %%
# import os
# from PIL import Image
# import numpy as np

# # Updated paths for CT, MRI, and PET images, and output path
# CT_path = "D:/Dataset/images/ct full"
# MRI_path = "D:/Dataset/images/mri full"
# PET_path = "D:/Dataset/images/pet full"
# output_fused_path = "D:/Dataset/Fused Image/fused"

# # Ensure the fused output directory exists
# os.makedirs(output_fused_path, exist_ok=True)

# def get_all_files(folder):
#     # Retrieves all filenames in the folder for fast matching
#     return {filename for filename in os.listdir(folder)}

# def fuse_images(ct_image_path, mri_image_path, pet_image_path, output_path):
#     # Load and process CT, MRI, and PET images
#     ct_image = Image.open(ct_image_path).convert("L")
#     mri_image = Image.open(mri_image_path).convert("L")
#     pet_image = Image.open(pet_image_path).convert("L")

#     # Convert images to numpy arrays
#     ct_array = np.array(ct_image) / 255.0
#     mri_array = np.array(mri_image) / 255.0
#     pet_array = np.array(pet_image) / 255.0

#     # Resize MRI and PET if sizes differ
#     if ct_array.shape != mri_array.shape:
#         mri_image = mri_image.resize(ct_image.size)
#         mri_array = np.array(mri_image) / 255.0
#     if ct_array.shape != pet_array.shape:
#         pet_image = pet_image.resize(ct_image.size)
#         pet_array = np.array(pet_image) / 255.0

#     # Fusion (average of three modalities)
#     fusion_array = (ct_array + mri_array + pet_array) / 3 * 255
#     fusion_array = fusion_array.astype(np.uint8)

#     # Save fusion image and handle potential errors
#     try:
#         fusion_image = Image.fromarray(fusion_array)
#         fusion_image.save(output_path)
#         print(f"Fusion image saved at {output_path}")
#     except Exception as e:
#         print(f"Error saving fusion image at {output_path}: {e}")

# def process_folder(ct_folder, mri_folder, pet_folder, output_folder, ct_extension=".png", mri_extension=".jpg", pet_extension=".png"):
#     # Load all files for fast matching
#     all_mri_files = get_all_files(mri_folder)
#     all_pet_files = get_all_files(pet_folder)
    
#     print(f"Processing CT files in {ct_folder}, MRI files in {mri_folder}, and PET files in {pet_folder}")
    
#     # Debugging: List available files in MRI and PET directories
#     print(f"Available MRI files in {mri_folder}: {sorted(list(all_mri_files))[:10]}...")  # Showing first 10 for brevity
#     print(f"Available PET files in {pet_folder}: {sorted(list(all_pet_files))[:10]}...")  # Showing first 10 for brevity

#     for ct_filename in os.listdir(ct_folder):
#         if ct_filename.endswith(ct_extension):
#             # Extract base name without extension (e.g., "ct1001" from "ct1001.png")
#             base_name = os.path.splitext(ct_filename)[0]
#             mri_filename = f"mri{base_name[2:]}{mri_extension}"  # MRI counterpart (e.g., "mri1001.jpg")
#             pet_filename = f"pet{base_name[2:]}{pet_extension}"  # PET counterpart (e.g., "pet1001.jpg")
            
#             ct_image_path = os.path.join(ct_folder, ct_filename)
            
#             # Debugging output for matching
#             print(f"Attempting to match CT file {ct_filename} with MRI file {mri_filename} and PET file {pet_filename}")
            
#             # Check if both MRI and PET counterparts exist
#             if mri_filename in all_mri_files and pet_filename in all_pet_files:
#                 mri_image_path = os.path.join(mri_folder, mri_filename)
#                 pet_image_path = os.path.join(pet_folder, pet_filename)
#                 output_path = os.path.join(output_folder, ct_filename)
#                 print(f"Processing {ct_filename} with MRI counterpart {mri_filename} and PET counterpart {pet_filename}...")
#                 fuse_images(ct_image_path, mri_image_path, pet_image_path, output_path)
#             else:
#                 # Additional debugging for missing files
#                 if mri_filename not in all_mri_files:
#                     print(f"Missing MRI file: {mri_filename}")
#                 if pet_filename not in all_pet_files:
#                     print(f"Missing PET file: {pet_filename}")

# # Process the updated dataset with appropriate extensions
# print("Processing dataset for fusion...")
# process_folder(CT_path, MRI_path, PET_path, output_fused_path, ct_extension=".png", mri_extension=".jpg", pet_extension=".png")

# print("All fusion images created and saved in the fused folder.")

# %%
# # CT_path = "D:/Dataset/images/ct full"a
# MRI_path = "D:/Dataset/images/mri full"
# PET_path = "D:/Dataset/images/pet full"

# %%
# import os
# from PIL import Image
# import numpy as np

# # Paths for dataset and output
# train_ct_path = "D:/Dataset/images/CT/trainA"
# train_mri_path = "D:/Dataset/images/MRI/trainB"
# train_pet_path = "D:/Dataset/images/PET/trainc"
# test_ct_path = "D:/Dataset/images/CT/testA"
# test_mri_path = "D:/Dataset/images/MRI/testB"
# test_pet_path = "D:/Dataset/images/PET/testc"
# output_train_path = "D:/Dataset/Fused Image/train"
# output_test_path = "D:/Dataset/Fused Image/test"

# # Ensure output directories exist and create if not
# os.makedirs(output_train_path, exist_ok=True)
# os.makedirs(output_test_path, exist_ok=True)

# def get_all_files(folder):
#     # Retrieves all filenames in the folder for fast matching
#     return {filename for filename in os.listdir(folder)}

# def fuse_images(ct_image_path, mri_image_path, pet_image_path, output_path):
#     # Load and process CT, MRI, and PET images
#     ct_image = Image.open(ct_image_path).convert("L")
#     mri_image = Image.open(mri_image_path).convert("L")
#     pet_image = Image.open(pet_image_path).convert("L")

#     # Convert images to numpy arrays
#     ct_array = np.array(ct_image) / 255.0
#     mri_array = np.array(mri_image) / 255.0
#     pet_array = np.array(pet_image) / 255.0

#     # Resize MRI and PET if sizes differ
#     if ct_array.shape != mri_array.shape:
#         mri_image = mri_image.resize(ct_image.size)
#         mri_array = np.array(mri_image) / 255.0
#     if ct_array.shape != pet_array.shape:
#         pet_image = pet_image.resize(ct_image.size)
#         pet_array = np.array(pet_image) / 255.0

#     # Fusion (average of three modalities)
#     fusion_array = (ct_array + mri_array + pet_array) / 3 * 255
#     fusion_array = fusion_array.astype(np.uint8)

#     # Save fusion image and handle potential errors
#     try:
#         fusion_image = Image.fromarray(fusion_array)
#         fusion_image.save(output_path)
#         print(f"Fusion image saved at {output_path}")
#     except Exception as e:
#         print(f"Error saving fusion image at {output_path}: {e}")

# def process_folder(ct_folder, mri_folder, pet_folder, output_folder, ct_extension=".png", mri_extension=".jpg", pet_extension=".jpg"):
#     # Load all files for fast matching
#     all_mri_files = get_all_files(mri_folder)
#     all_pet_files = get_all_files(pet_folder)
    
#     print(f"Processing CT files in {ct_folder}, MRI files in {mri_folder}, and PET files in {pet_folder}")
    
#     # Debugging: List available files in MRI and PET directories
#     print(f"Available MRI files in {mri_folder}: {sorted(list(all_mri_files))[:10]}...")  # Showing first 10 for brevity
#     print(f"Available PET files in {pet_folder}: {sorted(list(all_pet_files))[:10]}...")  # Showing first 10 for brevity

#     for ct_filename in os.listdir(ct_folder):
#         if ct_filename.endswith(ct_extension):
#             # Extract base name without extension (e.g., "ct1001" from "ct1001.png")
#             base_name = os.path.splitext(ct_filename)[0]
#             mri_filename = f"mri{base_name[2:]}{mri_extension}"  # MRI counterpart (e.g., "mri1001.jpg")
#             pet_filename = f"pet{base_name[2:]}{pet_extension}"  # PET counterpart (e.g., "pet1001.jpg")
            
#             ct_image_path = os.path.join(ct_folder, ct_filename)
            
#             # Debugging output for matching
#             print(f"Attempting to match CT file {ct_filename} with MRI file {mri_filename} and PET file {pet_filename}")
            
#             # Check if both MRI and PET counterparts exist
#             if mri_filename in all_mri_files and pet_filename in all_pet_files:
#                 mri_image_path = os.path.join(mri_folder, mri_filename)
#                 pet_image_path = os.path.join(pet_folder, pet_filename)
#                 output_path = os.path.join(output_folder, ct_filename)
#                 print(f"Processing {ct_filename} with MRI counterpart {mri_filename} and PET counterpart {pet_filename}...")
#                 fuse_images(ct_image_path, mri_image_path, pet_image_path, output_path)
#             else:
#                 # Additional debugging for missing files
#                 if mri_filename not in all_mri_files:
#                     print(f"Missing MRI file: {mri_filename}")
#                 if pet_filename not in all_pet_files:
#                     print(f"Missing PET file: {pet_filename}")

# # Process train and test datasets with appropriate extensions
# print("Processing training dataset...")
# process_folder(train_ct_path, train_mri_path, train_pet_path, output_train_path, ct_extension=".png", mri_extension=".jpg", pet_extension=".png")

# print("Processing test dataset...")
# process_folder(test_ct_path, test_mri_path, test_pet_path, output_test_path, ct_extension=".png", mri_extension=".jpg", pet_extension=".png")

# print("All fusion images created and saved in the fusion_output folder.")

# %%
# CoAtNet model

# %%
# !pip install torch torchvision einops scikit-learn

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from einops import rearrange
from einops.layers.torch import Rearrange
from sklearn.model_selection import train_test_split
import numpy as np
import os
from PIL import Image
from torchvision import transforms
import torch.optim as optim

# %%
import torch
import torch.nn as nn

from einops import rearrange
from einops.layers.torch import Rearrange


def conv_3x3_bn(inp, oup, image_size, downsample=False):
    stride = 1 if downsample == False else 2
    return nn.Sequential(
        nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
        nn.BatchNorm2d(oup),
        nn.GELU()
    )


class PreNorm(nn.Module):
    def __init__(self, dim, fn, norm):
        super().__init__()
        self.norm = norm(dim)
        self.fn = fn

    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)


class SE(nn.Module):
    def __init__(self, inp, oup, expansion=0.25):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(oup, int(inp * expansion), bias=False),
            nn.GELU(),
            nn.Linear(int(inp * expansion), oup, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y


class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout=0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)


class MBConv(nn.Module):
    def __init__(self, inp, oup, image_size, downsample=False, expansion=4):
        super().__init__()
        self.downsample = downsample
        stride = 1 if self.downsample == False else 2
        hidden_dim = int(inp * expansion)

        if self.downsample:
            self.pool = nn.MaxPool2d(3, 2, 1)
            self.proj = nn.Conv2d(inp, oup, 1, 1, 0, bias=False)

        if expansion == 1:
            self.conv = nn.Sequential(
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride,
                          1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.GELU(),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )
        else:
            self.conv = nn.Sequential(
                # pw
                # down-sample in the first conv
                nn.Conv2d(inp, hidden_dim, 1, stride, 0, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.GELU(),
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, 1, 1,
                          groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.GELU(),
                SE(inp, hidden_dim),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )
        
        self.conv = PreNorm(inp, self.conv, nn.BatchNorm2d)

    def forward(self, x):
        if self.downsample:
            return self.proj(self.pool(x)) + self.conv(x)
        else:
            return x + self.conv(x)


class Attention(nn.Module):
    def __init__(self, inp, oup, image_size, heads=8, dim_head=32, dropout=0.):
        super().__init__()
        inner_dim = dim_head * heads
        project_out = not (heads == 1 and dim_head == inp)

        self.ih, self.iw = image_size

        self.heads = heads
        self.scale = dim_head ** -0.5

        # parameter table of relative position bias
        self.relative_bias_table = nn.Parameter(
            torch.zeros((2 * self.ih - 1) * (2 * self.iw - 1), heads))

        coords = torch.meshgrid((torch.arange(self.ih), torch.arange(self.iw)))
        coords = torch.flatten(torch.stack(coords), 1)
        relative_coords = coords[:, :, None] - coords[:, None, :]

        relative_coords[0] += self.ih - 1
        relative_coords[1] += self.iw - 1
        relative_coords[0] *= 2 * self.iw - 1
        relative_coords = rearrange(relative_coords, 'c h w -> h w c')
        relative_index = relative_coords.sum(-1).flatten().unsqueeze(1)
        self.register_buffer("relative_index", relative_index)

        self.attend = nn.Softmax(dim=-1)
        self.to_qkv = nn.Linear(inp, inner_dim * 3, bias=False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, oup),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(
            t, 'b n (h d) -> b h n d', h=self.heads), qkv)

        dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale

        # Use "gather" for more efficiency on GPUs
        relative_bias = self.relative_bias_table.gather(
            0, self.relative_index.repeat(1, self.heads))
        relative_bias = rearrange(
            relative_bias, '(h w) c -> 1 c h w', h=self.ih*self.iw, w=self.ih*self.iw)
        dots = dots + relative_bias

        attn = self.attend(dots)
        out = torch.matmul(attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        out = self.to_out(out)
        return out


class Transformer(nn.Module):
    def __init__(self, inp, oup, image_size, heads=8, dim_head=32, downsample=False, dropout=0.):
        super().__init__()
        hidden_dim = int(inp * 4)

        self.ih, self.iw = image_size
        self.downsample = downsample

        if self.downsample:
            self.pool1 = nn.MaxPool2d(3, 2, 1)
            self.pool2 = nn.MaxPool2d(3, 2, 1)
            self.proj = nn.Conv2d(inp, oup, 1, 1, 0, bias=False)

        self.attn = Attention(inp, oup, image_size, heads, dim_head, dropout)
        self.ff = FeedForward(oup, hidden_dim, dropout)

        self.attn = nn.Sequential(
            Rearrange('b c ih iw -> b (ih iw) c'),
            PreNorm(inp, self.attn, nn.LayerNorm),
            Rearrange('b (ih iw) c -> b c ih iw', ih=self.ih, iw=self.iw)
        )

        self.ff = nn.Sequential(
            Rearrange('b c ih iw -> b (ih iw) c'),
            PreNorm(oup, self.ff, nn.LayerNorm),
            Rearrange('b (ih iw) c -> b c ih iw', ih=self.ih, iw=self.iw)
        )

    def forward(self, x):
        if self.downsample:
            x = self.proj(self.pool1(x)) + self.attn(self.pool2(x))
        else:
            x = x + self.attn(x)
        x = x + self.ff(x)
        return x


class CoAtNet(nn.Module):
    def __init__(self, image_size, in_channels, num_blocks, channels, num_classes=1000, block_types=['C', 'C', 'T', 'T']):
        super().__init__()
        ih, iw = image_size
        block = {'C': MBConv, 'T': Transformer}

        self.s0 = self._make_layer(
            conv_3x3_bn, in_channels, channels[0], num_blocks[0], (ih // 2, iw // 2))
        self.s1 = self._make_layer(
            block[block_types[0]], channels[0], channels[1], num_blocks[1], (ih // 4, iw // 4))
        self.s2 = self._make_layer(
            block[block_types[1]], channels[1], channels[2], num_blocks[2], (ih // 8, iw // 8))
        self.s3 = self._make_layer(
            block[block_types[2]], channels[2], channels[3], num_blocks[3], (ih // 16, iw // 16))
        self.s4 = self._make_layer(
            block[block_types[3]], channels[3], channels[4], num_blocks[4], (ih // 32, iw // 32))

        self.pool = nn.AvgPool2d(ih // 32, 1)
        self.fc = nn.Linear(channels[-1], num_classes, bias=False)

    def forward(self, x):
        x = self.s0(x)
        x = self.s1(x)
        x = self.s2(x)
        x = self.s3(x)
        x = self.s4(x)

        x = self.pool(x).view(-1, x.shape[1])
        x = self.fc(x)
        return x

    def _make_layer(self, block, inp, oup, depth, image_size):
        layers = nn.ModuleList([])
        for i in range(depth):
            if i == 0:
                layers.append(block(inp, oup, image_size, downsample=True))
            else:
                layers.append(block(oup, oup, image_size))
        return nn.Sequential(*layers)


def coatnet_0():
    num_blocks = [2, 2, 3, 5, 2]            # L
    channels = [64, 96, 192, 384, 768]      # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_1():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [64, 96, 192, 384, 768]      # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_2():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [128, 128, 256, 512, 1026]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_3():
    num_blocks = [2, 2, 6, 14, 2]           # L
    channels = [192, 192, 384, 768, 1536]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def coatnet_4():
    num_blocks = [2, 2, 12, 28, 2]          # L
    channels = [192, 192, 384, 768, 1536]   # D
    return CoAtNet((224, 224), 3, num_blocks, channels, num_classes=1000)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


if __name__ == '__main__':
    img = torch.randn(1, 3, 224, 224)

    net = coatnet_0()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_1()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_2()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_3()
    out = net(img)
    print(out.shape, count_parameters(net))

    net = coatnet_4()
    out = net(img)
    print(out.shape, count_parameters(net))
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# torch.Size([1, 1000]) 17789624
# torch.Size([1, 1000]) 33170624
# torch.Size([1, 1000]) 55767564
# torch.Size([1, 1000]) 117724480
# torch.Size([1, 1000]) 203960368

# %%
# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Example for pretrained models
])

# %%
# Define the dataset class
class MedicalImageDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('L')  # Convert image to grayscale
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

    def __len__(self):
        return len(self.image_paths)

# %%
# Function to visualize inputs
def visualize_inputs(dataloader, num_images=5):
    data_iter = iter(dataloader)
    images, labels = next(data_iter)

    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i in range(num_images):
        img = images[i].cpu().squeeze(0)  # Remove channel dimension for grayscale
        axes[i].imshow(img, cmap='gray')  # Display in grayscale
        axes[i].set_title(f"Label: {'Fused' if labels[i].item() == 0 else 'Non-Fused'}")
        axes[i].axis('off')
    plt.show()

# %%
# Dataset Directory Structure
fused_dir = 'D:/Brain Tumour Segmentation using Coatnet/Dataset/Fused/'
non_fused_dir = 'D:/Brain Tumour Segmentation using Coatnet/Dataset/Without Fused/'

# %%
# Get the list of fused and non-fused image files
fused_image_paths = [os.path.join(fused_dir, f) for f in os.listdir(fused_dir) if f.endswith(('.png', '.jpg'))]
non_fused_image_paths = [os.path.join(non_fused_dir, f) for f in os.listdir(non_fused_dir) if f.endswith(('.png', '.jpg'))]

# %%
# Create labels (0 for fused, 1 for non-fused)
fused_labels = [0] * len(fused_image_paths)
non_fused_labels = [1] * len(non_fused_image_paths)

# %%
# Combine images and labels
image_paths = fused_image_paths + non_fused_image_paths
labels = fused_labels + non_fused_labels

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
# Create dataset and dataloaders
dataset = MedicalImageDataset(image_paths, labels, transform=transform)
train_loader = DataLoader(dataset, batch_size=16, shuffle=True)

# Visualize input images
visualize_inputs(train_loader)

# %%
# Function to check if paths exist
def check_image_paths(image_paths):
    for path in image_paths:
        if not os.path.exists(path):
            print(f"Warning: Image file does not exist: {path}")

# %%
# Get the list of fused and non-fused image files
fused_image_paths = [os.path.join(fused_dir, f) for f in os.listdir(fused_dir) if f.endswith('.png')]
non_fused_image_paths = [os.path.join(non_fused_dir, f) for f in os.listdir(non_fused_dir) if f.endswith('.png') or f.endswith('.jpg')]

# Combine both fused and non-fused image paths and their corresponding labels
image_paths = fused_image_paths + non_fused_image_paths
labels = [0] * len(fused_image_paths) + [1] * len(non_fused_image_paths)  # Assuming 0 for fused and 1 for non-fused

# Check the paths before proceeding
check_image_paths(image_paths)

# %%
from PIL import Image

class MedicalImageDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('L')  # 'L' converts to grayscale
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

    def __len__(self):
        return len(self.image_paths)

# %%
# Split the data into training and validation sets
train_paths, val_paths, train_labels, val_labels = train_test_split(image_paths, labels, test_size=0.2, random_state=42)

# %%
# Create datasets and dataloaders
train_dataset = MedicalImageDataset(train_paths, train_labels, transform=transform)
val_dataset = MedicalImageDataset(val_paths, val_labels, transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
# Define your model (CoAtNet or any other model you'd like to use)
# Placeholder model (you should replace this with your actual CoAtNet model)
class SimpleCoAtNet(nn.Module):
    def __init__(self):
        super(SimpleCoAtNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64*224*224, 2)  # Assuming output size of 224x224 images

    def forward(self, x):
        x = self.conv1(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor for the fully connected layer
        x = self.fc1(x)
        return x

# %%
# Instantiate the model
model = SimpleCoAtNet()  # Replace with your actual CoAtNet model
model.to('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# SimpleCoAtNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=3211264, out_features=2, bias=True)
# )

# %%
# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training and Evaluation Functions
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0

    for images, labels in train_loader:
        if images is None:  # Skip if image loading failed
            continue

        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_preds += (predicted == labels).sum().item()
        total_preds += labels.size(0)

    avg_loss = running_loss / len(train_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

def evaluate(model, val_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0

    with torch.no_grad():
        for images, labels in val_loader:
            if images is None:  # Skip if image loading failed
                continue

            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            correct_preds += (predicted == labels).sum().item()
            total_preds += labels.size(0)

    avg_loss = running_loss / len(val_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

# %%
# Training Loop
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_epochs = 10
for epoch in range(num_epochs):
    train_loss, train_accuracy = train(model, train_loader, criterion, optimizer, device)
    val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

    print(f"Epoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch [1/10]
# Train Loss: 93.1175, Train Accuracy: 48.57%
# Validation Loss: 18.5216, Validation Accuracy: 48.67%
# Epoch [2/10]
# Train Loss: 12.7367, Train Accuracy: 56.35%
# Validation Loss: 17.7940, Validation Accuracy: 49.69%
# Epoch [3/10]
# Train Loss: 10.4443, Train Accuracy: 60.39%
# Validation Loss: 17.3237, Validation Accuracy: 40.08%
# Epoch [4/10]
# Train Loss: 8.8253, Train Accuracy: 64.07%
# Validation Loss: 17.6860, Validation Accuracy: 48.88%
# Epoch [5/10]
# Train Loss: 6.6800, Train Accuracy: 68.58%
# Validation Loss: 16.6471, Validation Accuracy: 49.18%
# Epoch [6/10]
# Train Loss: 6.3098, Train Accuracy: 69.78%
# Validation Loss: 20.7030, Validation Accuracy: 41.10%
# Epoch [7/10]
# Train Loss: 5.3041, Train Accuracy: 71.19%
# Validation Loss: 17.6544, Validation Accuracy: 43.46%
# Epoch [8/10]
# Train Loss: 4.5567, Train Accuracy: 73.39%
# Validation Loss: 15.5386, Validation Accuracy: 47.24%
# Epoch [9/10]
# Train Loss: 3.6336, Train Accuracy: 75.74%
# ...

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Confusion Matrix Calculation
def compute_confusion_matrix(model, data_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return confusion_matrix(all_labels, all_preds)

# Generate confusion matrix
cm = compute_confusion_matrix(model, val_loader, device)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Tumour', 'Non-tumour'])
cm_display.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
